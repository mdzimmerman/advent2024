# %%
import matplotlib.pyplot as plt
#import networkx as nx
import graphviz
import day24

# %%
test2 = day24.Graph("test2.txt")

# %%
dot = graphviz.Digraph()

for c in test2.connection:
    dot.edge(c.in1, c.out)
    dot.edge(c.in2, c.out)
dot.format = "png"
dot.body.append('{')
dot.body.append('rank = same;')
dot.body.append('edge[style=invis];')
dot.body.append('x00 -> y00 -> x01 -> y01 -> x02 -> y02 -> x03 -> y03 -> x04 -> y04;')
dot.body.append('}')
dot.body.append('{')
dot.body.append('rank = same;')
dot.body.append('edge[style=invis];')
dot.body.append('z00 -> z01 -> z02 -> z03 -> z04 -> z05 -> z06 -> z07 -> z08 -> z09 -> z10 -> z11 -> z12;')
dot.body.append('}') 
dot

# %%
o
